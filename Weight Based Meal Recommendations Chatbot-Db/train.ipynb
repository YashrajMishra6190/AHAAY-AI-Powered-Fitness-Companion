# %%
import pymongo
import pandas as pd

def connect_mongodb():
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    db = client["chatbot-db"]
    return db

def load_data(db, collection_name):
    collection = db[collection_name]
    data = list(collection.find({}, {"_id": 0, "question": 1, "answer": 1}))
    return pd.DataFrame(data)

db = connect_mongodb()
collections = [
    "Male_Underweight", "Male_Normalweight", "Male_Overweight", "Male_Obesity",
    "Female_Underweight", "Female_Normalweight", "Female_Overweight", "Female_Obesity"
]

dataframes = {collection: load_data(db, collection) for collection in collections}

# %%
dataframes
# Out:
# {'Male_Underweight':                                              question  \
#  0   What should I eat to gain weight in a healthy ...
#  1   How many calories should I consume daily to gain?
#  2   What are some high-protein foods to include in...
#  3                 Can I eat junk food to gain weight?
#  4              Should I take weight gain supplements?
#  5   What are the best drinks to help with weight g...
#  6                      How can I improve my appetite?
#  7   How much protein do I need daily for weight gain?
#  8     What role do carbohydrates play in weight gain?
#  9                    Should I avoid cardio exercises?
#  10  What are some quick and healthy snacks for wei...
#  11  How often should I eat to gain weight effectiv...
#  12      What is the best time to eat for weight gain?
#  13        Can I drink milk every day for weight gain?
#  14               How much water should I drink daily?
#  15              Are there any weight gain meal plans?
#  16    Can eating late at night help with weight gain?
#  17            How important is sleep for weight gain?
#  18                  Can stress affect my weight gain?
#  19  What are good sources of healthy fats for weig...
#  20       Should I take multivitamins for weight gain?
#  21  How long does it take to see results in weight...
#  22                  Can I eat fast food occasionally?
#  23              Do I need to track my calories daily?
#  24  Should I drink protein shakes before or after ...
#  25    What exercises should I do to gain muscle mass?
#  26   Can drinking fruit juices help with weight gain?
#  27         Is eating eggs daily good for weight gain?
#  28     Can I gain weight if I have a fast metabolism?
#  29  Should I consult a nutritionist for a weight g...
#
#                                                 answer
#  0   Focus on calorie-dense foods like nuts, avocad...
#  1   Your calorie intake depends on your height, we...
#  2   Include eggs, chicken, fish, legumes, dairy pr...
#  3   It's best to focus on nutritious, whole foods ...
#  4   Whole foods should be your priority, but weigh...
#  5   Smoothies, milkshakes, whole milk, and protein...
#  6   Eat smaller meals more frequently, include app...
#  7   Aim for 1.2-2.0 grams of protein per kilogram ...
#  8   Carbohydrates provide energy and help with mus...
#  9   No, but limit excessive cardio and focus more ...
#  10  Nuts, trail mix, peanut butter on toast, yogur...
#  11  Eat at least every 2-3 hours, including snacks...
#  12  Spread your meals throughout the day and inclu...
#  13  Yes, full-fat milk is an excellent source of c...
#  14  Stay hydrated but avoid drinking too much wate...
#  15  Yes, a meal plan can include oatmeal with nuts...
#  16  Eating a balanced meal or snack before bed can...
#  17  Sleep is crucial for muscle growth and overall...
#  18  Yes, stress can reduce appetite and hinder wei...
#  19  Include avocados, olive oil, nuts, seeds, and ...
#  20  Multivitamins can help if you're missing essen...
#  21  With a consistent diet and exercise plan, noti...
#  22  Occasionally, yes, but focus on nutrient-dense...
#  23  Tracking calories can help ensure you're eatin...
#  24  Drinking a protein shake after a workout helps...
#  25  Strength training exercises like squats, deadl...
#  26  Yes, natural fruit juices contain calories and...
#  27  Yes, eggs are a great source of protein and he...
#  28  Yes, by eating calorie-dense foods frequently ...
#  29  If you're struggling with weight gain, consult...  ,
#  'Male_Normalweight':                                              question  \
#  0   How can I maintain my current weight while sta...
#  1   What should my daily calorie intake be to main...
#  2   How much protein do I need daily for overall h...
#  3   What are the best sources of healthy carbohydr...
#  4   Can I eat cheat meals while maintaining my wei...
#  5                How much water should I drink daily?
#  6   Should I follow a specific diet plan to stay fit?
#  7   What are the best exercises to stay fit withou...
#  8         Is it okay to consume dairy products daily?
#  9      How important is sleep for weight maintenance?
#  10           Can stress affect my weight maintenance?
#  11                 Should I take dietary supplements?
#  12   What are the best snacks for maintaining weight?
#  13                Can I drink alcohol without gaining
#  14    How often should I exercise to maintain weight?
#  15                          Can I eat carbs at night?
#  16  What is the best way to track my weight withou...
#  17    How can I stay active without going to the gym?
#  18  Are meal replacement shakes good for maintaini...
#  19           What role do healthy fats play in weight
#  20    Can I eat desserts while maintaining my weight?
#  21   How can I avoid overeating at social gatherings?
#  22      Should I fast occasionally for better health?
#  23         How can I ensure I'm getting enough fiber?
#  24                  Can I eat fast food occasionally?
#  25  What are some quick and healthy breakfast opti...
#  26  How can I improve my digestion for better weig...
#  27  What are some good meal prep ideas for a busy ...
#  28  How important is portion control in weight mai...
#  29  Should I consult a nutritionist to maintain my...
#
#                                                 answer
#  0   Maintain a balanced diet with lean proteins, w...
#  1   It depends on your age, height, and activity l...
#  2   Aim for 0.8-1.2 grams of protein per kilogram ...
#  3   Whole grains, fruits, vegetables, and legumes ...
#  4   Yes, occasional cheat meals are fine as long a...
#  5   Aim for at least 2-3 liters of water per day, ...
#  6   No need for extreme diets; just focus on a bal...
#  7   A mix of strength training and moderate cardio...
#  8   Yes, in moderation. Opt for low-fat or full-fa...
#  9   Very important. Aim for 7-9 hours of sleep per...
#  10  Yes, stress can lead to unhealthy eating habit...
#  11  Only if needed. Whole foods should be your pri...
#  12  Nuts, Greek yogurt, hummus with veggies, and w...
#  13  Moderation is key. Limit alcohol intake and op...
#  14  At least 150 minutes of moderate exercise or 7...
#  15  Yes, timing doesn’t matter as long as your tot...
#  16  Weigh yourself once a week and focus on overal...
#  17  Walking, cycling, bodyweight exercises, and ou...
#  18  Whole foods are better, but shakes can be usef...
#  19  Healthy fats (avocados, nuts, olive oil) suppo...
#  20  Yes, but in moderation. Opt for healthier dess...
#  21  Eat a small healthy meal beforehand, drink wat...
#  22  Intermittent fasting can be beneficial but isn...
#  23  Eat whole grains, fruits, vegetables, and legu...
#  24  Yes, but choose healthier options and limit fr...
#  25  Oatmeal with nuts, eggs with whole wheat toast...
#  26  Eat fiber-rich foods, stay hydrated, and inclu...
#  27  Prepare meals like grilled chicken with quinoa...
#  28  Portion control helps prevent overeating and k...
#  29  If you're unsure about your dietary needs, con...  ,
#  'Male_Overweight':                                              question  \
#  0               How can I start losing weight safely?
#  1              What is the best diet for weight loss?
#  2   How many calories should I consume daily to lo...
#  3                  Should I cut carbs to lose weight?
#  4         How much exercise do I need to lose weight?
#  5               Can I lose weight without exercising?
#  6        What are the best exercises for weight loss?
#  7   How much protein should I eat while losing wei...
#  8   Is intermittent fasting effective for weight l...
#  9             How important is sleep for weight loss?
#  10          Can drinking water help with weight loss?
#  11  Are diet pills or supplements necessary for we...
#  12      How can I manage food cravings while dieting?
#  13                      Can stress cause weight gain?
#  14          How can I eat out without gaining weight?
#  15           Is meal prepping useful for weight loss?
#  16                Should I avoid fats to lose weight?
#  17   Can I drink alcohol while trying to lose weight?
#  18                 How do I stop late-night snacking?
#  19        Should I track my calories for weight loss?
#  20  How long does it take to see weight loss results?
#  21      Can drinking green tea help with weight loss?
#  22    What are the healthiest snacks for weight loss?
#  23                   Should I avoid sugar completely?
#  24  How can I stay motivated during my weight loss...
#  25         Can weight training help with weight loss?
#  26    How can I prevent loose skin after weight loss?
#  27        What is the best breakfast for weight loss?
#  28  How do I avoid weight regain after losing weight?
#  29   Should I consult a nutritionist for weight loss?
#
#                                                 answer
#  0   Start by eating a balanced diet, reducing port...
#  1   A diet rich in lean proteins, whole grains, fr...
#  2   A typical recommendation is to reduce daily in...
#  3   No need to eliminate carbs completely. Focus o...
#  4   Aim for at least 150-300 minutes of moderate-i...
#  5   Yes, but combining a healthy diet with exercis...
#  6   Cardio exercises like running, cycling, and sw...
#  7   Aim for 1.2-1.5 grams of protein per kilogram ...
#  8   Yes, intermittent fasting can help control cal...
#  9   Very important. Lack of sleep can lead to weig...
#  10  Yes, staying hydrated boosts metabolism and he...
#  11  Not necessary. A balanced diet and exercise ar...
#  12  Eat fiber-rich foods, stay hydrated, and avoid...
#  13  Yes, stress increases cortisol levels, leading...
#  14  Choose grilled over fried foods, control porti...
#  15  Yes, it helps control portions and ensures hea...
#  16  No, healthy fats from avocados, nuts, and oliv...
#  17  Limit alcohol intake as it adds empty calories...
#  18  Stick to a meal schedule, stay hydrated, and o...
#  19  It helps increase awareness of food intake and...
#  20  Visible results can take 4-8 weeks, depending ...
#  21  Green tea contains antioxidants that may boost...
#  22  Nuts, Greek yogurt, fruits, and hummus with ve...
#  23  Reduce added sugars, but natural sugars from f...
#  24  Set small, achievable goals, track progress, a...
#  25  Yes, it helps build muscle, which boosts metab...
#  26  Gradual weight loss, strength training, and st...
#  27  High-protein breakfasts like eggs, oatmeal, or...
#  28  Maintain a balanced diet, exercise regularly, ...
#  29  Yes, if you're unsure about the best approach,...  ,
#  'Male_Obesity':                                              question  \
#  0        How can I start losing weight if I am obese?
#  1               What are the health risks of obesity?
#  2   How many calories should I eat daily to lose w...
#  3           Is surgery a good option for weight loss?
#  4             What is the best diet plan for obesity?
#  5         How much exercise do I need to lose weight?
#  6      What exercises are safe for obese individuals?
#  7             How do I stay motivated to lose weight?
#  8                             Can obesity be genetic?
#  9                 How does stress affect weight gain?
#  10          Can drinking water help with weight loss?
#  11               Should I avoid carbs to lose weight?
#  12   What are some healthy snack options for obesity?
#  13                     How do I prevent binge eating?
#  14          Is meal prepping helpful for weight loss?
#  15                 Can I lose weight without dieting?
#  16                  How do I handle emotional eating?
#  17  Is intermittent fasting effective for obese in...
#  18             Can weight training help with obesity?
#  19            How important is sleep for weight loss?
#  20                   Should I completely avoid sugar?
#  21                           Can obesity be reversed?
#  22          How can I eat out without gaining weight?
#  23  What is the best breakfast for obesity managem...
#  24   How can I improve digestion while losing weight?
#  25             Are weight loss supplements necessary?
#  26                 How do I stop late-night snacking?
#  27                      Can obesity cause depression?
#  28  How do I maintain weight loss after losing wei...
#  29  Should I consult a doctor before starting a we...
#
#                                                 answer
#  0   Begin with small changes—adopt a balanced diet...
#  1   Obesity increases the risk of diabetes, heart ...
#  2   A deficit of 500-1000 calories per day can hel...
#  3   Weight-loss surgery may be an option for those...
#  4   A high-protein, fiber-rich diet with whole gra...
#  5   Aim for at least 150 minutes of moderate-inten...
#  6   Low-impact exercises like swimming, walking, a...
#  7   Set realistic goals, track progress, and seek ...
#  8   Genetics can play a role, but lifestyle choice...
#  9   Stress can increase cortisol levels, leading t...
#  10  Yes, staying hydrated helps control hunger and...
#  11  Focus on complex carbs like whole grains, legu...
#  12  Greek yogurt, nuts, fruits, boiled eggs, and h...
#  13  Eat balanced meals at regular intervals and pr...
#  14  Yes, it ensures portion control and prevents u...
#  15  A healthy lifestyle with portion control and r...
#  16  Identify triggers, practice stress management ...
#  17  It can help, but should be done under medical ...
#  18  Yes, building muscle increases metabolism and ...
#  19  Poor sleep can increase hunger hormones and le...
#  20  Reduce added sugars, but natural sugars from f...
#  21  Yes, with consistent lifestyle changes includi...
#  22  Choose grilled over fried foods, watch portion...
#  23  A high-protein, fiber-rich breakfast like eggs...
#  24  Eat fiber-rich foods, drink plenty of water, a...
#  25  No, focus on a natural, healthy diet and exerc...
#  26  Establish a meal routine, stay hydrated, and k...
#  27  Yes, obesity and mental health are linked, so ...
#  28  Continue a balanced diet, stay active, and mon...
#  29  Yes, especially if you have any medical condit...  ,
#  'Female_Underweight':                                              question  \
#  0             How can I gain weight in a healthy way?
#  1     What are the health risks of being underweight?
#  2      How many calories should I eat to gain weight?
#  3        Should I eat more frequently to gain weight?
#  4   What are the best protein sources for weight g...
#  5        Can strength training help with weight gain?
#  6        Is it safe to drink weight gain supplements?
#  7         Does being underweight affect menstruation?
#  8           How can I increase my appetite naturally?
#  9          What are some high-calorie healthy snacks?
#  10                      Can stress cause weight loss?
#  11               Should I drink milk for weight gain?
#  12   Does eating late at night help with weight gain?
#  13       How does being underweight affect pregnancy?
#  14    What types of fats should I eat to gain weight?
#  15  How can I prevent bloating while trying to gai...
#  16  Can drinking water before meals reduce my appe...
#  17            How does metabolism affect weight gain?
#  18    Are smoothies a good option for gaining weight?
#  19  Should I avoid cardio exercises if I want to g...
#  20      Can hormone imbalances cause low body weight?
#  21        Is it okay to eat junk food to gain weight?
#  22  What should my macronutrient ratio be for weig...
#  23  How can I gain weight without increasing body ...
#  24          Does sleeping more help with weight gain?
#  25  Can I still gain weight if I have a small appe...
#  26  Should I take multivitamins to help with weigh...
#  27        How do I know if my weight gain is healthy?
#  28  What are some easy ways to add extra calories ...
#  29  When should I see a doctor about being underwe...
#
#                                                 answer
#  0   Focus on nutrient-dense foods like nuts, dairy...
#  1   It can lead to weakened immunity, osteoporosis...
#  2   Consume 300-500 extra calories per day for gra...
#  3   Yes, eating 5-6 small meals a day with protein...
#  4   Lean meats, fish, eggs, dairy, lentils, tofu, ...
#  5   Yes, it helps build muscle mass, which contrib...
#  6   It depends on the ingredients; natural food so...
#  7   Yes, it can cause irregular periods or even st...
#  8   Eat small, frequent meals, include more spices...
#  9   Nuts, avocados, hummus, cheese, peanut butter,...
#  10  Yes, chronic stress can suppress appetite and ...
#  11  Yes, whole milk is a great source of protein a...
#  12  As long as the calories consumed contribute to...
#  13  It can increase the risk of complications like...
#  14  Healthy fats like olive oil, nuts, seeds, and ...
#  15  Avoid carbonated drinks and eat smaller, more ...
#  16  Yes, but if your goal is weight gain, drink wa...
#  17  A fast metabolism burns calories quickly, maki...
#  18  Yes, smoothies with milk, nut butter, fruits, ...
#  19  Limit excessive cardio and focus more on stren...
#  20  Yes, conditions like hyperthyroidism can affec...
#  21  No, unhealthy food can lead to other health pr...
#  22  A balanced intake of carbs, proteins, and fats...
#  23  Strength training and consuming lean proteins ...
#  24  Quality sleep is essential for overall health ...
#  25  Yes, by eating energy-dense foods in smaller p...
#  26  If you have deficiencies, a doctor may recomme...
#  27  Monitor body composition, muscle vs. fat gain,...
#  28  Add cheese, nut butter, olive oil, and seeds t...
#  29  If you experience unexplained weight loss, fat...  ,
#  'Female_Normalweight':                                              question  \
#  0   What is the ideal diet plan for a woman with a...
#  1            How much protein should I consume daily?
#  2     Is it okay to include carbohydrates in my diet?
#  3   How often should I exercise to maintain my wei...
#  4              What is the best way to stay hydrated?
#  5           How does stress impact weight management?
#  6                What are some healthy snack options?
#  7               Can I occasionally indulge in sweets?
#  8                   How does sleep affect metabolism?
#  9                  Should I take dietary supplements?
#  10     What’s the best way to manage portion control?
#  11               Can yoga help in weight maintenance?
#  12            How can I prevent weight gain as I age?
#  13               How many meals should I eat per day?
#  14  Is intermittent fasting beneficial if I have a...
#  15       What foods should I avoid for better health?
#  16                        How do I improve digestion?
#  17         Is alcohol consumption okay in moderation?
#  18        How can I boost my energy levels naturally?
#  19                    What’s a good pre-workout meal?
#  20      How important is strength training for women?
#  21                           Can I eat late at night?
#  22                          How do I manage bloating?
#  23          What’s a good post-workout recovery meal?
#  24                          Can I drink coffee daily?
#  25          How do I balance work and healthy eating?
#  26                  Should I track my calorie intake?
#  27     What’s the best way to control sugar cravings?
#  28         How does fiber help in weight maintenance?
#  29           Should I get a health checkup regularly?
#
#                                                 answer
#  0   A balanced diet including lean proteins, whole...
#  1   Around 0.8-1.2 grams per kilogram of body weig...
#  2   Yes, complex carbohydrates like quinoa, oats, ...
#  3   At least 150 minutes of moderate exercise per ...
#  4   Drinking at least 2-3 liters of water daily an...
#  5   Chronic stress can lead to emotional eating an...
#  6   Nuts, Greek yogurt, hummus with veggies, and f...
#  7   Yes, moderation is key. Opt for healthier alte...
#  8   Poor sleep can slow metabolism and lead to inc...
#  9   If you have nutrient deficiencies, consult a d...
#  10  Using smaller plates, mindful eating, and list...
#  11  Yes, it helps with flexibility, strength, and ...
#  12  Strength training, a balanced diet, and an act...
#  13  Three balanced meals with healthy snacks in be...
#  14  It can help regulate eating habits, but it's n...
#  15  Highly processed foods, trans fats, and excess...
#  16  Eating fiber-rich foods, staying hydrated, and...
#  17  Yes, but it should be limited to avoid excess ...
#  18  Prioritizing sleep, staying active, and eating...
#  19  A mix of carbohydrates and protein, like a ban...
#  20  It helps maintain muscle mass, boosts metaboli...
#  21  It’s okay if you choose healthy options and do...
#  22  Eating slowly, avoiding carbonated drinks, and...
#  23  Protein-rich foods like eggs, Greek yogurt, or...
#  24  Yes, in moderation. Avoid too much sugar and c...
#  25  Meal prepping and choosing healthy on-the-go o...
#  26  It can help maintain awareness, but focus on f...
#  27  Eating protein-rich meals, staying hydrated, a...
#  28  It aids digestion, keeps you full, and regulat...
#  29  Yes, routine health checkups help monitor over...  ,
#  'Female_Overweight':                                              question  \
#  0   What are the best weight loss strategies for o...
#  1   How many calories should I consume to lose wei...
#  2   What are the best exercises for overweight women?
#  3         Can I lose weight without going to the gym?
#  4             What should my daily meal plan include?
#  5                     How do I control food cravings?
#  6   Is intermittent fasting effective for overweig...
#  7                  How does sleep affect weight loss?
#  8       What are some healthy snacks for weight loss?
#  9                       Can stress cause weight gain?
#  10           Should I completely avoid carbohydrates?
#  11               How much water should I drink daily?
#  12      Can drinking green tea help with weight loss?
#  13  How do I stay motivated during my weight loss ...
#  14                    How do I stop emotional eating?
#  15       Is meal prepping beneficial for weight loss?
#  16          What is the best way to measure progress?
#  17       How do I handle social events while dieting?
#  18        Are protein shakes helpful for weight loss?
#  19                   How often should I weigh myself?
#  20                Does metabolism slow down with age?
#  21  Can I lose weight without cutting out my favou...
#  22  What’s the best way to deal with weight loss p...
#  23  How important is strength training for weight ...
#  24        Can obesity-related conditions be reversed?
#  25  What are some easy breakfast ideas for weight ...
#  26                 Is walking enough for weight loss?
#  27                How do I avoid late-night snacking?
#  28           How can I naturally boost my metabolism?
#  29   Should I consult a nutritionist for weight loss?
#
#                                                 answer
#  0   A combination of a calorie-controlled diet, re...
#  1   A moderate deficit of 500-750 calories per day...
#  2   Walking, swimming, cycling, yoga, and strength...
#  3   Yes, home workouts, brisk walking, bodyweight ...
#  4   Lean proteins, whole grains, vegetables, fruit...
#  5   Eat protein-rich meals, stay hydrated, get eno...
#  6   It can be beneficial when combined with a bala...
#  7   Poor sleep can disrupt hormones that regulate ...
#  8   Nuts, Greek yogurt, hummus with vegetables, bo...
#  9   Yes, chronic stress can lead to overeating and...
#  10  No, choose complex carbs like whole grains, qu...
#  11  At least 2.5-3 liters per day to stay hydrated...
#  12  Green tea can boost metabolism slightly but sh...
#  13  Set small, realistic goals, track progress, an...
#  14  Identify triggers, practice mindful eating, an...
#  15  Yes, it helps control portions and ensures acc...
#  16  Use body measurements, progress photos, and cl...
#  17  Plan ahead, choose healthier options, and prac...
#  18  They can be a convenient option but should not...
#  19  Once a week at the same time of day for consis...
#  20  Yes, but regular exercise and proper nutrition...
#  21  Yes, practice portion control and moderation i...
#  22  Adjust your diet, change your workout routine,...
#  23  Very important, as it helps build muscle, whic...
#  24  Many health conditions can improve with weight...
#  25  Scrambled eggs with vegetables, Greek yogurt w...
#  26  Walking can help with weight loss when combine...
#  27  Have a satisfying dinner, drink herbal tea, an...
#  28  Eat enough protein, stay active, drink water, ...
#  29  Yes, a professional can provide personalized a...  ,
#  'Female_Obesity':                                              question  \
#  0   What is the best diet plan for women with obes...
#  1                How can I lose weight if I am obese?
#  2   How many calories should I consume daily to lo...
#  3        What are the best exercises for obese women?
#  4                            Can obesity be reversed?
#  5                How much water should I drink daily?
#  6                       How can I prevent overeating?
#  7              What role do hormones play in obesity?
#  8      Is intermittent fasting effective for obesity?
#  9                          What foods should I avoid?
#  10           Can obesity lead to other health issues?
#  11                     How can I control my cravings?
#  12  What is the best way to track weight loss prog...
#  13                 Should I completely cut out carbs?
#  14             How do I manage stress-related eating?
#  15              Can I lose weight without exercising?
#  16               What are some healthy snack options?
#  17                 How does sleep affect weight loss?
#  18                  Are weight loss supplements safe?
#  19  How can I stay motivated during my weight loss...
#  20                            Can obesity be genetic?
#  21  What are the best breakfast options for obese ...
#  22                How do I avoid late-night snacking?
#  23     Is it possible to lose belly fat specifically?
#  24  What are some easy meal prep ideas for weight ...
#  25            How does gut health affect weight loss?
#  26      Should I consult a dietitian for weight loss?
#  27  What’s the best way to break a weight loss pla...
#  28  Can weight loss surgery be an option for obesity?
#  29     How do I handle social pressure while dieting?
#
#                                                 answer
#  0   A balanced diet with controlled portions, rich...
#  1   Start with small, sustainable changes in your ...
#  2   A deficit of 500-1000 calories per day can lea...
#  3   Low-impact activities like walking, swimming, ...
#  4   Yes, through lifestyle changes, proper diet, r...
#  5   At least 3 liters per day to stay hydrated and...
#  6   Practice mindful eating, control portion sizes...
#  7   Hormonal imbalances, such as thyroid disorders...
#  8   It can be beneficial for some individuals, but...
#  9   Processed foods, sugary beverages, fried foods...
#  10  Yes, it increases the risk of diabetes, heart ...
#  11  Eat protein-rich meals, stay hydrated, get eno...
#  12  Use a combination of weight measurements, body...
#  13  No, focus on whole, complex carbs like brown r...
#  14  Practice relaxation techniques, such as medita...
#  15  While diet plays a major role, regular physica...
#  16  Nuts, yogurt, hummus with veggies, boiled eggs...
#  17  Poor sleep can disrupt metabolism and increase...
#  18  It’s best to focus on natural weight loss meth...
#  19  Set realistic goals, track progress, join a su...
#  20  Genetics can play a role, but lifestyle choice...
#  21  Protein-rich options like eggs, Greek yogurt, ...
#  22  Have a satisfying dinner, drink herbal tea, an...
#  23  Spot reduction isn’t possible, but a combinati...
#  24  Preparing lean protein, cutting veggies in adv...
#  25  A balanced gut microbiome can improve digestio...
#  26  Yes, professional guidance can help create a p...
#  27  Change up your exercise routine, adjust your c...
#  28  In severe cases, bariatric surgery can be cons...
#  29  Communicate your goals, plan ahead for social ...  }

# %%
def preprocess_text(df):
    df['question'] = df['question'].str.strip().str.lower()
    df['answer'] = df['answer'].str.strip().str.lower()
    return df

for collection in collections:
    dataframes[collection] = preprocess_text(dataframes[collection])

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Trainer, TrainingArguments
from datasets import Dataset

model_name = "facebook/bart-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

def tokenize_function(examples):
    return tokenizer(examples['question'], examples['answer'], truncation=True, padding='max_length')

# Combine all dataframes into one
combined_df = pd.concat(dataframes.values())
dataset = Dataset.from_pandas(combined_df)
tokenized_dataset = dataset.map(tokenize_function, batched=True)

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_dataset,
)

trainer.train()
# Out:
# Map:   0%|          | 0/240 [00:00<?, ? examples/s]
# Asking to pad to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no padding.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# /opt/anaconda3/lib/python3.12/site-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 33
#      16 training_args = TrainingArguments(
#      17     output_dir="./results",
#      18     evaluation_strategy="epoch",
#    (...)
#      23     weight_decay=0.01,
#      24 )
#      26 trainer = Trainer(
#      27     model=model,
#      28     args=training_args,
#      29     train_dataset=tokenized_dataset,
#      30     eval_dataset=tokenized_dataset,
#      31 )
# ---> 33 trainer.train()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/trainer.py:2241, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2239         hf_hub_utils.enable_progress_bars()
#    2240 else:
# -> 2241     return inner_training_loop(
#    2242         args=args,
#    2243         resume_from_checkpoint=resume_from_checkpoint,
#    2244         trial=trial,
#    2245         ignore_keys_for_eval=ignore_keys_for_eval,
#    2246     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/trainer.py:2500, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2498 update_step += 1
#    2499 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2500 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches)
#    2501 for i, inputs in enumerate(batch_samples):
#    2502     step += 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/trainer.py:5180, in Trainer.get_batch_samples(self, epoch_iterator, num_batches)
#    5178 for _ in range(num_batches):
#    5179     try:
# -> 5180         batch_samples += [next(epoch_iterator)]
#    5181     except StopIteration:
#    5182         break
#
# File /opt/anaconda3/lib/python3.12/site-packages/accelerate/data_loader.py:564, in DataLoaderShard.__iter__(self)
#     562 # We iterate one batch ahead to check when we are at the end
#     563 try:
# --> 564     current_batch = next(dataloader_iter)
#     565 except StopIteration:
#     566     yield
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/data/data_collator.py:92, in default_data_collator(features, return_tensors)
#      86 # In this function we'll make the assumption that all `features` in the batch
#      87 # have the same attributes.
#      88 # So we will look at the first element as a proxy for what attributes exist
#      89 # on the whole batch.
#      91 if return_tensors == "pt":
# ---> 92     return torch_default_data_collator(features)
#      93 elif return_tensors == "tf":
#      94     return tf_default_data_collator(features)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/data/data_collator.py:158, in torch_default_data_collator(features)
#     156             batch[k] = torch.from_numpy(np.stack([f[k] for f in features]))
#     157         else:
# --> 158             batch[k] = torch.tensor([f[k] for f in features])
#     160 return batch
#
# ValueError: expected sequence of length 30 at dim 1 (got 39)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Trainer, TrainingArguments
from datasets import Dataset
import torch

model_name = "facebook/bart-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move model to CPU if GPU memory is an issue
device = torch.device("cpu")
model.to(device)

def tokenize_function(examples):
    model_inputs = tokenizer(examples['question'], truncation=True, padding='max_length', max_length=128)
    labels = tokenizer(examples['answer'], truncation=True, padding='max_length', max_length=128)

    # Ensure labels are correctly formatted
    labels["input_ids"] = [
        [-100 if token == tokenizer.pad_token_id else token for token in label]
        for label in labels["input_ids"]
    ]
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Combine all dataframes into one
combined_df = pd.concat(dataframes.values())
dataset = Dataset.from_pandas(combined_df)
tokenized_dataset = dataset.map(tokenize_function, batched=True)

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=2,  # Small batch size
    per_device_eval_batch_size=2,   # Small batch size
    num_train_epochs=3,
    weight_decay=0.01,
    gradient_accumulation_steps=4,  # Accumulate gradients over 4 steps
    fp16=False,  # Disable mixed precision training if using CPU
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_dataset,
)

trainer.train()
# Out:
# Map:   0%|          | 0/240 [00:00<?, ? examples/s]
# /opt/anaconda3/lib/python3.12/site-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='90' max='90' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [90/90 00:51, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.168801</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.925376</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.844790</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/anaconda3/lib/python3.12/site-packages/transformers/modeling_utils.py:2810: UserWarning: Moving the following attributes in the config to the generation config: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# TrainOutput(global_step=90, training_loss=2.780869377983941, metrics={'train_runtime': 52.6063, 'train_samples_per_second': 13.687, 'train_steps_per_second': 1.711, 'total_flos': 54876281241600.0, 'train_loss': 2.780869377983941, 'epoch': 3.0})

# %%
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', '__index_level_0__'],
#     num_rows: 240
# })

# %%
8 * 30
# Out:
# 240

# %%
eval_results = trainer.evaluate()
print(f"Evaluation results: {eval_results}")
# Out:
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 00:03]
#     </div>
# Evaluation results: {'eval_loss': 1.8447895050048828, 'eval_runtime': 3.2319, 'eval_samples_per_second': 74.259, 'eval_steps_per_second': 37.129, 'epoch': 3.0}

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model=model, tokenizer=tokenizer)

def generate_summary(answer):
    summary = summarizer(answer, max_length=50, min_length=250, do_sample=False)
    return summary[0]['summary_text']

# Example usage
sample_answer = combined_df.iloc[0]['answer']
summary = generate_summary(sample_answer)
print(f"Original Answer: {sample_answer}")
print(f"Summary: {summary}")
# Out:
# Device set to use mps:0
# Your min_length=250 must be inferior than your max_length=50.
# Your max_length is set to 50, but your input_length is only 35. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# /opt/anaconda3/lib/python3.12/site-packages/transformers/generation/utils.py:1432: UserWarning: Unfeasible length constraints: `min_length` (250) is larger than the maximum possible length (50). Generation will stop at the defined maximum length. You should decrease the minimum length and/or increase the maximum length.
#   warnings.warn(
# Original Answer: focus on calorie-dense foods like nuts, avocados, whole grains, lean meats, and dairy. eat frequent meals and include protein-rich snacks.
# Summary: focus on protein-rich foods like nuts, avocados, whole grains, lean meats, and dairy. eat a balanced diet, including fruits, vegetables, and whole grains. avoid processed foods, and avoid processed meats. focus on

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
import torch

# Load the trained model and tokenizer
model_name = "facebook/bart-base"
model_path = "./results"  # Path where the model is saved
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

# Move model to CPU if necessary
device = torch.device("cpu")
model.to(device)

# Create a text generation pipeline
generator = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0 if torch.mps.is_available() else -1)

def generate_response(question, answer):
    input_text = f"question: {question} answer: {answer}"
    response = generator(input_text, max_length=128, num_return_sequences=1)
    return response[0]['generated_text']

def main():
    print("Welcome to the AI AHAAY Meal Planner Chatbot!")

    while True:
        # Ask for gender
        gender = input("Are you male or female? (Type 'male' or 'female'): ").strip().lower()
        if gender not in ["male", "female"]:
            print("Invalid input. Please type 'male' or 'female'.")
            continue

        # Ask for weight category
        weight_category = input("Select your weight category (underweight, normalweight, overweight, obesity): ").strip().lower()
        if weight_category not in ["underweight", "normalweight", "overweight", "obesity"]:
            print("Invalid input. Please select a valid weight category.")
            continue

        # Form the collection name
        collection_name = f"{gender.capitalize()}_{weight_category.capitalize()}"

        # Load the relevant data
        data = dataframes[collection_name]

        while True:
            # Ask for the question
            question = input("Enter your question (or type 'exit' to stop): ").strip().lower()
            if question == "exit":
                break

            # Find the matching answer
            matching_row = data[data['question'].str.contains(question, case=False, na=False)]
            if not matching_row.empty:
                answer = matching_row.iloc[0]['answer']
                response = generate_response(question, answer)
                print("Response:", response)
            else:
                print("No matching answer found.")

        # Ask if the user wants to continue
        continue_chat = input("Do you want to ask more questions? (Type 'yes' or 'no'): ").strip().lower()
        if continue_chat != "yes":
            break

    print("Thank you for using the AI AHAAY Meal Planner Chatbot!")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 7
#       5 model_name = "facebook/bart-base"
#       6 model_path = "./results"  # Path where the model is saved
# ----> 7 tokenizer = AutoTokenizer.from_pretrained(model_path)
#       8 model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
#      10 # Move model to CPU if necessary
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:901, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     899         config = AutoConfig.for_model(**config_dict)
#     900     else:
# --> 901         config = AutoConfig.from_pretrained(
#     902             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     903         )
#     904 config_tokenizer_class = config.tokenizer_class
#     905 if hasattr(config, "auto_map") and "AutoTokenizer" in config.auto_map:
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:1112, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1109         if pattern in str(pretrained_model_name_or_path):
#    1110             return CONFIG_MAPPING[pattern].from_dict(config_dict, **unused_kwargs)
# -> 1112 raise ValueError(
#    1113     f"Unrecognized model in {pretrained_model_name_or_path}. "
#    1114     f"Should have a `model_type` key in its {CONFIG_NAME}, or contain one of the following strings "
#    1115     f"in its name: {', '.join(CONFIG_MAPPING.keys())}"
#    1116 )
#
# ValueError: Unrecognized model in ./results. Should have a `model_type` key in its config.json, or contain one of the following strings in its name: albert, align, altclip, aria, aria_text, audio-spectrogram-transformer, autoformer, bamba, bark, bart, beit, bert, bert-generation, big_bird, bigbird_pegasus, biogpt, bit, blenderbot, blenderbot-small, blip, blip-2, bloom, bridgetower, bros, camembert, canine, chameleon, chinese_clip, chinese_clip_vision_model, clap, clip, clip_text_model, clip_vision_model, clipseg, clvp, code_llama, codegen, cohere, cohere2, colpali, conditional_detr, convbert, convnext, convnextv2, cpmant, ctrl, cvt, dab-detr, dac, data2vec-audio, data2vec-text, data2vec-vision, dbrx, deberta, deberta-v2, decision_transformer, deformable_detr, deit, depth_anything, depth_pro, deta, detr, diffllama, dinat, dinov2, dinov2_with_registers, distilbert, donut-swin, dpr, dpt, efficientformer, efficientnet, electra, emu3, encodec, encoder-decoder, ernie, ernie_m, esm, falcon, falcon_mamba, fastspeech2_conformer, flaubert, flava, fnet, focalnet, fsmt, funnel, fuyu, gemma, gemma2, git, glm, glpn, got_ocr2, gpt-sw3, gpt2, gpt_bigcode, gpt_neo, gpt_neox, gpt_neox_japanese, gptj, gptsan-japanese, granite, granitemoe, granitemoeshared, granitevision, graphormer, grounding-dino, groupvit, helium, hiera, hubert, ibert, idefics, idefics2, idefics3, idefics3_vision, ijepa, imagegpt, informer, instructblip, instructblipvideo, jamba, jetmoe, jukebox, kosmos-2, layoutlm, layoutlmv2, layoutlmv3, led, levit, lilt, llama, llava, llava_next, llava_next_video, llava_onevision, longformer, longt5, luke, lxmert, m2m_100, mamba, mamba2, marian, markuplm, mask2former, maskformer, maskformer-swin, mbart, mctct, mega, megatron-bert, mgp-str, mimi, mistral, mixtral, mllama, mobilebert, mobilenet_v1, mobilenet_v2, mobilevit, mobilevitv2, modernbert, moonshine, moshi, mpnet, mpt, mra, mt5, musicgen, musicgen_melody, mvp, nat, nemotron, nezha, nllb-moe, nougat, nystromformer, olmo, olmo2, olmoe, omdet-turbo, oneformer, open-llama, openai-gpt, opt, owlv2, owlvit, paligemma, patchtsmixer, patchtst, pegasus, pegasus_x, perceiver, persimmon, phi, phi3, phimoe, pix2struct, pixtral, plbart, poolformer, pop2piano, prophetnet, pvt, pvt_v2, qdqbert, qwen2, qwen2_5_vl, qwen2_audio, qwen2_audio_encoder, qwen2_moe, qwen2_vl, rag, realm, recurrent_gemma, reformer, regnet, rembert, resnet, retribert, roberta, roberta-prelayernorm, roc_bert, roformer, rt_detr, rt_detr_resnet, rt_detr_v2, rwkv, sam, seamless_m4t, seamless_m4t_v2, segformer, seggpt, sew, sew-d, siglip, siglip_vision_model, speech-encoder-decoder, speech_to_text, speech_to_text_2, speecht5, splinter, squeezebert, stablelm, starcoder2, superglue, superpoint, swiftformer, swin, swin2sr, swinv2, switch_transformers, t5, table-transformer, tapas, textnet, time_series_transformer, timesformer, timm_backbone, timm_wrapper, trajectory_transformer, transfo-xl, trocr, tvlt, tvp, udop, umt5, unispeech, unispeech-sat, univnet, upernet, van, video_llava, videomae, vilt, vipllava, vision-encoder-decoder, vision-text-dual-encoder, visual_bert, vit, vit_hybrid, vit_mae, vit_msn, vitdet, vitmatte, vitpose, vitpose_backbone, vits, vivit, wav2vec2, wav2vec2-bert, wav2vec2-conformer, wavlm, whisper, xclip, xglm, xlm, xlm-prophetnet, xlm-roberta, xlm-roberta-xl, xlnet, xmod, yolos, yoso, zamba, zamba2, zoedepth
